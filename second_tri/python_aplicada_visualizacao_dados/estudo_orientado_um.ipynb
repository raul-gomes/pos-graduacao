# %%
import pandas as pd

# %%
data = {
    'Cidade': ['São Paulo', 'Rio de Janeiro', 'Fortalezao', 'Natal'],
    'Qtd Clientes': [1034, 2345, 678, 456]
    }

df = pd.DataFrame(data)

df
# Out:
#            Cidade  Qtd Clientes
# 0       São Paulo          1034
# 1  Rio de Janeiro          2345
# 2      Fortalezao           678
# 3           Natal           456

# %%
df.plot(kind='bar', x='Cidade', y='Qtd Clientes')
# Out:
# <Axes: xlabel='Cidade'>
